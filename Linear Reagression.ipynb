# %%
import numpy as np

# %%
x = np.array([10,9,2,15,10,16,11,16])

# %%
Mx=np.sum(x)
My=np.sum(y)
Mxy=np.sum(x*y)
Mxsqr=np.sum(x*x)
Mysqr=np.sum(y*y)

# %%
n=len(x)
temp=(My*(Mxsqr))-(Mx*Mxy)
temp2=(n*(Mxsqr))-(Mx*Mx)
b_0=temp/temp2
print(b_0)
# Out:
# 12.584627964022895

# %%
temp=(n*Mxy)-(Mx*My)
temp2=(n*Mxsqr)-(Mx*Mx)

# %%
b_1=temp/temp2
print(b_1)
# Out:
# 4.58789860997547

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
y_pred=b_0+b_1*x
plt.plot(x,y_pred,'g')
plt.show()

# %% [markdown]
# op
