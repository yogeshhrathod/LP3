# %%
import socket
s = socket.socket()
host = socket.gethostname()
port=7890
server_socket= s.connect((host,port))

# %%
p=13
q=29
n = p*q
phi = (p-1)*(q-1)

# %%
import math
e =2
while (e<phi):
    if(math.gcd(e,phi)==1):
        break;
    else:
        e=e+1
print(e)
# Out:
# 5

# %%
i=1
d=((i*phi)+1)/e
while(d-math.floor(d)!=0):
    i=i+1
    d=((i*phi)+1)/e
print(d)
# Out:
# 269.0

# %%
length=str(n)
en_key=str(e)
length=length.encode('ascii')
key=en_key.encode('ascii')
s.send(length)
s.send(key)
msg=s.recv(1024)
msg= int(msg.decode('ascii'))
print(msg,d)
plain_text=(pow(msg,int(d)))
plain_text%=n
s.close()
print('Message is :')
print(plain_text)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-f4757baba8cf> in <module>()
#       3 length=length.encode('ascii')
#       4 key=en_key.encode('ascii')
# ----> 5 s.send(length)
#       6 s.send(key)
#       7 msg=s.recv(1024)
#
# OSError: [WinError 10038] An operation was attempted on something that is not a socket
